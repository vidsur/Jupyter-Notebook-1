# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\sures'

# %%
credit = pd.read_csv(r"C:\Users\sures\OneDrive\Documents\VS\Course 5\default of credit card clients.csv", header =1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# 1    11888
# 2    18112
# Name: SEX, dtype: int64

# %%
# Instead of a group by, use seaborn to plot the number of males and females
Female = credit[credit['SEX']==2]
sns.factorplot('SEX',data=credit, kind='count', aspect=1.5, legend=True,hue='SEX')

# %%
# Instead of a group by, use seaborn to plot by Education
sns.factorplot('EDUCATION',data=credit, kind='count', aspect=1.5, legend=True)

# %%
# Instead of a group by, use seaborn to plot by Marital Status
sns.factorplot('MARRIAGE',data=credit, kind='count', aspect=1.5, legend=True)

# %%
g = sns.factorplot('EDUCATION', data=credit, hue='SEX', kind='count', aspect=1.75)

# %%
# Number of  who survived in each class grouped by sex. Also total was found for each class grouped by sex.
import numpy as np
credit.pivot_table('MARRIAGE', 'SEX', 'EDUCATION', aggfunc=np.sum, margins=True)
# Out:
# EDUCATION   0      1      2     3    4    5   6    All
# SEX
# 1          14   7046   8439  2944   67  143  36  18689
# 2          10  10444  12929  4044  130  270  40  27867
# All        24  17490  21368  6988  197  413  76  46556

# %%
# Lets do a factorplot of customers split into different age groups
sns.factorplot('AGE', data=credit, kind='count', hue='SEX', order=[20,40,60,70],aspect=2)

# %%
credit['age_bin']=pd.cut(x = credit['AGE'],
                        bins = [20, 35, 50, 65, 85], 
                        labels = [0, 1, 2,3])
credit
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
sns.factorplot('age_bin', data=credit, kind='count', hue='SEX')

# %%
credit.dropna(inplace=True)

# %%
credit
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'age_bin'],
#       dtype='object')

# %%
#build our first histogram using the .hist method of matplotlib as follows; this example plots the 'LIMIT_BAL' variable:
plt.hist(credit['LIMIT_BAL'], bins=10)
plt.show()

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
#to create a comparison of any two features we must first set the two features equal to variables as follows; this is an example using 'PAY_0' to 'PAY_2'
x = credit['PAY_0']
y = credit['PAY_2']
plt.scatter(x,y)
plt.show()

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corrMat,vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...

# %%
credit.drop('ID', axis=1)
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
# ...
